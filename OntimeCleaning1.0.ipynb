# %%
import pandas as pd
import numpy as np
import sys
from pandas import DataFrame, read_csv

pd.set_option('display.max_columns', None)
pd.set_option('max_rows', 20)

# %%
file = r'/Users/Ben/Documents/AirlineOntimeData/extracted/On_Time_On_Time_Performance_2014_3.csv'

# %%
df = pd.read_csv(file)
# Out:
# /Users/Ben/Documents/AirlineOntimeData/venv/lib/python2.7/site-packages/pandas/io/parsers.py:1150: DtypeWarning: Columns (48,77,84) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %% [markdown]
# Try to figure out what columns 48, 77, 84 are

# %%
col = df.columns

# %%
df[col[48]].head(20)
# Out:
# 0     NaN
# 1       A
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: CancellationCode, dtype: object

# %%
df[col[77]].head(20)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: Div2Airport, dtype: object

# %%
df[col[84]].head(20)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: Div2TailNum, dtype: object

# %%
df.head(10)
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0  2014        1      3           7          5  2014-03-07            MQ
# 1  2014        1      3           8          6  2014-03-08            MQ
# 2  2014        1      3           9          7  2014-03-09            MQ
# 3  2014        1      3          10          1  2014-03-10            MQ
# 4  2014        1      3          11          2  2014-03-11            MQ
# 5  2014        1      3          12          3  2014-03-12            MQ
# 6  2014        1      3          13          4  2014-03-13            MQ
# 7  2014        1      3          14          5  2014-03-14            MQ
# 8  2014        1      3          15          6  2014-03-15            MQ
# 9  2014        1      3          16          7  2014-03-16            MQ
#
#    AirlineID Carrier TailNum  FlightNum  OriginAirportID  OriginAirportSeqID  \
# 0      20398      MQ  N679MQ       3431            11111             1111102
# ...

# %%
delcol = col[Div1Airport:Div5TailNum]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b63f15e6b544> in <module>()
# ----> 1 delcol = col[Div1Airport:Div5TailNum]
#
# NameError: name 'Div1Airport' is not defined
